# %% [markdown]
# <span style="font-size: 14pt">MIPT, Advanced ML, Autumn 2017</span>
#
# <span style="font-size: 16pt"> HW #2: ARMA, ARIMA
#
# <span style="color:blue; font-size: 12pt">Alexey Romanenko </span>,
# <span style="color:blue; font-size: 12pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
# - Лукишн Ю.П. Адаптивные методы краткосрочного прогнозирования временных рядов. Финансы и статистика. 2003, главы 1,4,5,7.
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_Aut_fall 401 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер>.ipnb``, к примеру -- ``ivanov_401_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Мы используем автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Напоминаем, что дедлайны жесткие, письма пришедшие после автоматически удаляются =( чтобы соблазна не было

# %% [markdown]
# <h1 align="center">Check Questions (20%)</h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1** Напишите уравнение временного ряда (в виде $y_t=f\left(y_{t-1}, \dots, y_1,~\varepsilon_{t},\dots, \varepsilon_{1}\right)$) которая соответствует модели:
#    * 1) ARIMA $(p=0,d=k,q=1)$,
#      - <Ответ>
#    * 2) ARIMA $(p=0,d=k+1,d=1)(P=1, D=1, Q=0)_s$,
#      - <Ответ>

# %% [markdown]
# **Вопрос 2**  Write canonic form of ARIMA model for the time series
#  - 1) $$y_t = a_1 y_{t-1} + a_2 y_{t-4} - a_1 a_2 y_{t-5} + \varepsilon_t$$ (Hint: seasnality period is equal to 4).
#  - 2) $$y_t = y_{t-d} + \varepsilon_t +b_2 + \varepsilon_{t-2} + B_1 \varepsilon_{t-s} + b_2 B_1 \varepsilon_{t-s-2} $$

# %% [markdown]
# **Вопрос 3** Покажите, что ARIMA$(p=0,d=2, q=2)$ эквивалентна модели Хольта (linear trend) при условиях:
# 		$$(1-В)^2Y_t = (1-\phi_1 В-\phi_2 В^2)\varepsilon_t$$
# 		$$\phi_1 = 2-\alpha-\alpha\beta, \text{ }\phi_2 = \alpha-1$$

# %% [markdown]
# **Вопрос 4**: Покажите, что для модели
#     $$AR(p)\colon \;\;\; y_t = \phi_1 y_{t-1} + \phi_2 y_{t-2} + \dots + \phi_p y_{t-p} + \varepsilon_t,$$**
#     где $y_t$ стационарный процесс с нулевым средним,$~~$
#     $\phi_1,\dots,\phi_p$ - константы ($\phi_p \neq 0$), $~~$
#     $\varepsilon_t$ несмещённый гауссовский шум с дисперсией $\sigma_\varepsilon^2 $
# выолнено:
#
#    * a) частный коэффициент автокорреляции
#    $$\phi_{\tau\tau} = \mathsf{E}[y_t-\hat y_t, y_{t+\tau} - \hat y_{t+\tau}]= \begin{cases}0 &, \tau>p; \\ f(\tau,p)>0 &, 0\leq\tau\leq p. \end{cases}$$
#
#   где $\hat y_t$ - прогноз $y_t$ согласно следующей регрессионной модели $$y_t = \sum_{j=1}^{\tau-1}\beta_j y_{t+j}$$
#     $\hat y_{t+\tau}$ - forecast of $y_{t\tau}$ with following regression model $$y_{t+\tau} = \sum_{j=1}^{\tau-1}\gamma_j y_{t+j}.$$
#
# <Ответ>

# %% [markdown]
# **Вопрос 5**: Покажите, что для модели
# $$MA(q)\colon \;\;\; y_t = \varepsilon_t + \theta_1\varepsilon_{t-1} + \theta_2\varepsilon_{t-2} + \dots + \theta_q \varepsilon_{t-q},$$
#    где $y_t$ стационарный процесс с нулевым средним,$~~$
#      $\theta_1,\dots,\theta_q$ - константы ($\theta_q \neq 0$), $~~$
#     $\varepsilon_t$ несмещённый гауссовский шум с дисперсией $\sigma_\varepsilon^2 $
# выолнено:
#
# * a) коэффициент корреляции
#    $$r_\tau=\begin{cases}0 &, \tau>q; \\ f(\tau,q)>0 &, \tau\leq q. \end{cases}$$
#
# <Answer>

# %% [markdown]
# **Вопрос 6** . Conclude in accordance with results above how to choose $p$ and $q$ parameters for ARMA model by looking at ACF and PACF.
#
# <Ответ>
#
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# <img src="p1.jpg">

# %% [markdown]
# <h1 align="center"> Practice</h1>
#
# <h2 align="center">  1. Download data for following data sets (10%)</h2>
# * 1) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">TS_dep36.csv</span> (105 TS of goods sales in the shop #36 of one real Retail Net, each TS correspond to an item in this shop )
# * 2) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">TS_dep42.csv</span> (105 TS of goods sales in shop #42 of one real Retail Net, each TS correspond to an item in this shop)
# * 3) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">TS_dep6.csv </span>(110 TS of goods sales in shop #6 of one real Retail Net, each TS correspond to an item in this shop)
#
# All data you can find by <a href='https://1drv.ms/f/s!AqGgzb5T4tvShb8iJuzFHOeXR11wOg'>link</a>
#
# * For each data set:
#       - 1) learn it's structure in csv-file and read it into Pandas data frame (be careful with parsing data)
#       - 2) plot each time series
#       - 3) answer the questions: is there seasonlaity, trend, changes in level in TS? If there is seasonality then define period of seasonality.

# %%
import numpy as np
npa = np.array
from datetime import datetime, timedelta
import pylab
import matplotlib.pyplot as plt
from matplotlib import gridspec
import pandas as pd
import math
import pandas.tseries.offsets as ofs
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa import stattools

import warnings as w
#import plotly.plotly as py
from IPython.display import Image

from utils import qualityMACAPE, qualityRMSE

# %matplotlib inline

# %%
ts36 = pd.read_csv('TS_dep36.csv', sep=';', decimal=',', parse_dates=True, dayfirst=False, index_col='Timestamp')
ts36[0:3]
# Out:
#             item 1758  item 40010  item 35731  item 96474  item 97519  \
# Timestamp
# 2005-12-05      0.000       0.000       2.484       0.000         0.0
# 2005-05-13      0.878       0.983       2.632       1.120         1.0
# 2005-05-14      0.332       1.346       2.016       0.302         1.0
#
#             item 75501  item 95519  item 93400  item 99826  item 57813  \
# Timestamp
# 2005-12-05       1.334           1           1         2.0           0
# 2005-05-13       3.514           4           0         1.0           0
# 2005-05-14       2.590           0           2         0.0           1
#
#                ...      item 65825  item 31454  item 29014  item 49139  \
# Timestamp      ...
# 2005-12-05     ...               7          12         0.0      66.324
# 2005-05-13     ...              16          17         0.0      69.952
# 2005-05-14     ...              11          12         0.0      35.366
#
#             item 42190  item 8110  item 80718  item 29092  item 76501  \
# Timestamp
# 2005-12-05      32.864         12          23          63          14
# 2005-05-13      34.024         24          30          97          13
# 2005-05-14      31.626         20           0          80          12
#
#             item 32258
# Timestamp
# 2005-12-05         177
# 2005-05-13          63
# 2005-05-14          94
#
# [3 rows x 105 columns]

# %%
ts36.loc[:, ts36.columns[range(5)]].plot(figsize=(15,15))
plt.show()

# %% [markdown]
# Здесь и далее будет рассматриваться одна колонка(для удобства)

# %%
res = sm.tsa.seasonal_decompose(ts36.loc[:, 'item 35731'].resample("M").mean().fillna(0))
resplot = res.plot()

# %% [markdown]
# Видим хороший убывающий тренд и некое подобие сезонности.

# %%
ts42 = pd.read_csv('TS_dep42.csv', sep=';', decimal='.', parse_dates=True, dayfirst=False, index_col='Timestamp')
ts42.loc["2006-01":"2006-2", ts42.columns[10:13]].plot(figsize=(15,15))
plt.show()
ts42[:1]
# Out:
#             item 558  item 834  item 883  item 1311  item 1396  item 1647  \
# Timestamp
# 2005-03-10       NaN       NaN       NaN        NaN        NaN        NaN
#
#             item 1689  item 1761  item 1969  item 2036     ...      \
# Timestamp                                                  ...
# 2005-03-10        NaN        NaN        NaN        NaN     ...
#
#             item 77539  item 79279  item 80510  item 82356  item 87639  \
# Timestamp
# 2005-03-10         NaN         NaN         NaN         NaN         NaN
#
#             item 88121  item 89103  item 89977  item 95417  item 96668
# Timestamp
# 2005-03-10         NaN         NaN         NaN         NaN         NaN
#
# [1 rows x 155 columns]

# %%
res = sm.tsa.seasonal_decompose(ts42.loc["2006-01-1":, 'item 558'].resample("M").mean().fillna(0))
resplot = res.plot()

# %% [markdown]
# Здесь тренда нет, зато сезонность более выраженная.

# %%
ts6 = pd.read_csv('TS_dep6.csv', sep=';', decimal='.', parse_dates=True, dayfirst=False, index_col='Timestamp')
ts6.head()
# Out:
#             item 1089  item 10960  item 1178  item 11827  item 1511  \
# Timestamp
# 2006-11-01        1.0         2.0        0.0         3.0        3.0
# 2006-11-02        2.0         2.0        4.0         0.0        0.0
# 2006-11-03        4.0         4.0        1.0         3.0        3.0
# 2006-11-04        0.0         3.0        2.0         1.0        1.0
# 2006-11-05        4.0         8.0        1.0         2.0        1.0
#
#             item 15934  item 16368  item 17248  item 18232  item 18291  \
# Timestamp
# 2006-11-01         0.0         0.0         2.0         3.0         4.0
# 2006-11-02         1.0         0.0         5.0         1.0         6.0
# 2006-11-03         1.0         0.0         5.0         6.0         7.0
# 2006-11-04         0.0         2.0         1.0         1.0         7.0
# 2006-11-05         1.0         2.0         6.0         5.0         6.0
#
#                ...      item 89787  item 91285  item 91845  item 93627  \
# Timestamp      ...
# 2006-11-01     ...             3.0         NaN         NaN         NaN
# 2006-11-02     ...             4.0         NaN         NaN         NaN
# 2006-11-03     ...             0.0         NaN         NaN         NaN
# 2006-11-04     ...             3.0         NaN         NaN         NaN
# 2006-11-05     ...             6.0         NaN         NaN         NaN
#
#             item 93634  item 96260  item 96880  item 97952  item 99146  \
# Timestamp
# 2006-11-01         NaN         NaN         NaN         NaN         NaN
# 2006-11-02         NaN         NaN         NaN         NaN         NaN
# 2006-11-03         NaN         NaN         NaN         NaN         NaN
# 2006-11-04         NaN         NaN         NaN         NaN         NaN
# 2006-11-05         NaN         NaN         NaN         NaN         NaN
#
#             item 99147
# Timestamp
# 2006-11-01         NaN
# 2006-11-02         NaN
# 2006-11-03         NaN
# 2006-11-04         NaN
# 2006-11-05         NaN
#
# [5 rows x 110 columns]

# %%
ts6.loc["2006-11-01":"2007-1-01", ts6.columns[0:3]].plot(figsize=(15,15))
plt.show()

# %%
res = sm.tsa.seasonal_decompose(ts6.loc['2006-11':'2007-01', 'item 1089'].resample("D").mean().fillna(0))
resplot = res.plot()

# %%
Кажется, ничего интересного тут нет,при том довольно большое значение ошибки.

# %% [markdown]
# <h2 align="center">2. ARIMA Model real TS (70%) </h2>
# You need to analyse a TS and build forecast with ARIMA model for it.
# Each student has its own TS: you can find id of yout TS that you need to forecast <a href="https://drive.google.com/open?id=1y5xgpgErIiJFYmXWB-eFYmQ6OUMocqP-VGpTIXLuzCw">here</a>.
# 37	Крахмалёв Денис Сергеевич	496а	TS_dep36	item 76210

# %% [markdown]
# **I. Build ARIMA forecast yourself **
#
# Also you can follow the next scheme:
#
#  * 0) read data for TS under consideration and use the first 80% of all length of the TS as train TS.
#  * 1) plot the graph of the train TS, preprocess data (delete tail, make calendar transformation if needed)
#  * 2) stabilize dispersion of the train TS through box-cox transformation if needed.
#  * 3) if the transformed train TS is non-stationary make it stationary (remember the power of differencing $d$).
#  * 4) plot ACF/PACF for  the transformed train TS in order to understand whether $AR(p)/MA(q)$ may be used.
#  * 5) select set of candidate parameters for ARMA (for the train TS)
#  * 6) train candidate ARIMA models (use $d$ from step 3), $p$, $q$ from step 5)), compare their AIC, choose the best model.
#  * 7) check test for unbiasedness, stationarity and non-autocorrelation of the residuals of the best ARIMA model; if the tests fail you need to review your choice.
#  * 8) build forecast for the initial TS (you need to transform it like in step 2)
#  * 9) build forecast interval for the last 20% of the transformed initial TS. Calculate loss MACAPE of your forecast. Does the forecast look appropriate?

# %%
ts36['val'] = ts36['item 76210']
ts = ts36.loc[:, ['val']]
ts.columns = ['val']
ts = ts["2005-05":"2006-5"]
ts = ts.resample("D").mean()
ts = ts.fillna(ts['val'].mean())
ts.plot(figsize=(15,5))
plt.show()

# %%
k = int(len(ts) * 0.8)
train_ts = ts.iloc[:k, :]
test_ts = ts.iloc[k:, :]

# %%
lam = 0.1

ts['val_boxcox'] = (np.array(ts['val']) ** lam + 1) ** (1 / lam) 
ts['val_boxcox'].plot(figsize=(15,5))
plt.show()

kpss_stat = stattools.kpss(np.array(ts['val_boxcox']))
print('diff 1 The KPSS test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ntable distribution: %s' % 
      (kpss_stat[0], kpss_stat[1], kpss_stat[2], kpss_stat[3]))
df_stat = stattools.adfuller(np.array(ts['val_boxcox']))
print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' % 
      (df_stat[0], df_stat[1], df_stat[2], df_stat[4]))
# Out:
# diff 1 The KPSS test statistic 0.371570,
# pvalue: 0.09
# maximal Lag: 17
# table distribution: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The Augmented Dickey-Fuller test statistic -8.523190,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4474498334928687, '5%': -2.8690765390453703, '10%': -2.5707847950750549}

# %%
res = sm.tsa.seasonal_decompose(ts['val'].fillna(0))
resplot = res.plot()

# %%
for p in range(1, 152, ):
    ts['val_d1'] = (ts['val'] - ts['val'].shift(p))
    ts2 = ts[p:]
  
    df_stat = stattools.adfuller(np.array(ts2['val_d1']))
    print('seasonDiff: %i The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' % 
          (p, df_stat[0], df_stat[1], df_stat[2], df_stat[4]))
# Out:
# seasonDiff: 1 The Augmented Dickey-Fuller test statistic -9.503913,
# pvalue: 0.00
# maximal Lag: 13
# critical values: {'1%': -3.4478619826418817, '5%': -2.869257669826291, '10%': -2.5708813583635131}
# seasonDiff: 2 The Augmented Dickey-Fuller test statistic -7.915449,
# pvalue: 0.00
# maximal Lag: 15
# critical values: {'1%': -3.448003816652923, '5%': -2.86931999731073, '10%': -2.5709145866785503}
# seasonDiff: 3 The Augmented Dickey-Fuller test statistic -7.134674,
# pvalue: 0.00
# maximal Lag: 17
# critical values: {'1%': -3.4481479670108381, '5%': -2.8693833397824413, '10%': -2.5709483564645725}
# seasonDiff: 4 The Augmented Dickey-Fuller test statistic -9.642075,
# pvalue: 0.00
# maximal Lag: 11
# critical values: {'1%': -3.4479090067294811, '5%': -2.8692783343881483, '10%': -2.5708923751111112}
# seasonDiff: 5 The Augmented Dickey-Fuller test statistic -11.193085,
# pvalue: 0.00
# maximal Lag: 9
# critical values: {'1%': -3.4478619826418817, '5%': -2.869257669826291, '10%': -2.5708813583635131}
# seasonDiff: 6 The Augmented Dickey-Fuller test statistic -7.296329,
# pvalue: 0.00
# maximal Lag: 17
# critical values: {'1%': -3.448294490928673, '5%': -2.869447722240253, '10%': -2.5709826810652689}
# seasonDiff: 7 The Augmented Dickey-Fuller test statistic -8.117252,
# pvalue: 0.00
# maximal Lag: 13
# critical values: {'1%': -3.4481479670108381, '5%': -2.8693833397824413, '10%': -2.5709483564645725}
# seasonDiff: 8 The Augmented Dickey-Fuller test statistic -7.160393,
# pvalue: 0.00
# maximal Lag: 15
# critical values: {'1%': -3.448294490928673, '5%': -2.869447722240253, '10%': -2.5709826810652689}
# seasonDiff: 9 The Augmented Dickey-Fuller test statistic -6.778332,
# pvalue: 0.00
# maximal Lag: 17
# critical values: {'1%': -3.4484434475193777, '5%': -2.8695131705108081, '10%': -2.571017574266393}
# seasonDiff: 10 The Augmented Dickey-Fuller test statistic -7.173545,
# pvalue: 0.00
# maximal Lag: 13
# critical values: {'1%': -3.448294490928673, '5%': -2.869447722240253, '10%': -2.5709826810652689}
# seasonDiff: 11 The Augmented Dickey-Fuller test statistic -8.004960,
# pvalue: 0.00
# maximal Lag: 10
# critical values: {'1%': -3.4481965417085849, '5%': -2.8694046837896692, '10%': -2.5709597356805545}
# seasonDiff: 12 The Augmented Dickey-Fuller test statistic -7.924418,
# pvalue: 0.00
# maximal Lag: 11
# critical values: {'1%': -3.448294490928673, '5%': -2.869447722240253, '10%': -2.5709826810652689}
# seasonDiff: 13 The Augmented Dickey-Fuller test statistic -7.215045,
# pvalue: 0.00
# maximal Lag: 13
# critical values: {'1%': -3.4484434475193777, '5%': -2.8695131705108081, '10%': -2.571017574266393}
# seasonDiff: 14 The Augmented Dickey-Fuller test statistic -7.379150,
# pvalue: 0.00
# maximal Lag: 13
# critical values: {'1%': -3.4484936508108239, '5%': -2.8695352280356556, '10%': -2.5710293341377715}
# seasonDiff: 15 The Augmented Dickey-Fuller test statistic -6.931234,
# pvalue: 0.00
# maximal Lag: 16
# critical values: {'1%': -3.4486972813047574, '5%': -2.8696246923288418, '10%': -2.571077032068342}
# seasonDiff: 16 The Augmented Dickey-Fuller test statistic -6.821778,
# pvalue: 0.00
# maximal Lag: 16
# critical values: {'1%': -3.4487489051519011, '5%': -2.8696473721448728, '10%': -2.5710891239349585}
# seasonDiff: 17 The Augmented Dickey-Fuller test statistic -6.960581,
# pvalue: 0.00
# maximal Lag: 16
# critical values: {'1%': -3.4488008203391201, '5%': -2.8696701795766368, '10%': -2.5711012838861036}
# seasonDiff: 18 The Augmented Dickey-Fuller test statistic -7.190458,
# pvalue: 0.00
# maximal Lag: 17
# critical values: {'1%': -3.4489055346552631, '5%': -2.8697161816205705, '10%': -2.5711258103550882}
# seasonDiff: 19 The Augmented Dickey-Fuller test statistic -20.214473,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4480996560263386, '5%': -2.8693621113224137, '10%': -2.570937038891028}
# seasonDiff: 20 The Augmented Dickey-Fuller test statistic -10.223015,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4483438698531952, '5%': -2.8694694186069092, '10%': -2.5709942482606229}
# seasonDiff: 21 The Augmented Dickey-Fuller test statistic -19.462761,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4481965417085849, '5%': -2.8694046837896692, '10%': -2.5709597356805545}
# seasonDiff: 22 The Augmented Dickey-Fuller test statistic -20.735066,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4482453822848496, '5%': -2.8694261442901396, '10%': -2.5709711770439507}
# seasonDiff: 23 The Augmented Dickey-Fuller test statistic -8.457932,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.448544133483233, '5%': -2.8695574079525565, '10%': -2.5710411593052713}
# seasonDiff: 24 The Augmented Dickey-Fuller test statistic -20.276378,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4483438698531952, '5%': -2.8694694186069092, '10%': -2.5709942482606229}
# seasonDiff: 25 The Augmented Dickey-Fuller test statistic -21.416428,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4483935212959844, '5%': -2.8694912343676497, '10%': -2.5710058791518109}
# seasonDiff: 26 The Augmented Dickey-Fuller test statistic -16.071649,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4484936508108239, '5%': -2.8695352280356556, '10%': -2.5710293341377715}
# seasonDiff: 27 The Augmented Dickey-Fuller test statistic -21.215747,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4484936508108239, '5%': -2.8695352280356556, '10%': -2.5710293341377715}
# seasonDiff: 28 The Augmented Dickey-Fuller test statistic -11.242817,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4486972813047574, '5%': -2.8696246923288418, '10%': -2.571077032068342}
# seasonDiff: 29 The Augmented Dickey-Fuller test statistic -10.515726,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4488008203391201, '5%': -2.8696701795766368, '10%': -2.5711012838861036}
# seasonDiff: 30 The Augmented Dickey-Fuller test statistic -10.439742,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.448853029339765, '5%': -2.8696931157043788, '10%': -2.5711135124984219}
# seasonDiff: 31 The Augmented Dickey-Fuller test statistic -10.584173,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4489055346552631, '5%': -2.8697161816205705, '10%': -2.5711258103550882}
# seasonDiff: 32 The Augmented Dickey-Fuller test statistic -10.661417,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4489583388155194, '5%': -2.869739378430086, '10%': -2.5711381780459002}
# seasonDiff: 33 The Augmented Dickey-Fuller test statistic -10.499311,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4490114443793214, '5%': -2.8697627072503757, '10%': -2.5711506161673716}
# seasonDiff: 34 The Augmented Dickey-Fuller test statistic -15.806959,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4489055346552631, '5%': -2.8697161816205705, '10%': -2.5711258103550882}
# seasonDiff: 35 The Augmented Dickey-Fuller test statistic -8.437514,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4491725955218655, '5%': -2.8698334971428574, '10%': -2.5711883591836733}
# seasonDiff: 36 The Augmented Dickey-Fuller test statistic -11.922353,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4491185700996199, '5%': -2.8698097654570507, '10%': -2.5711757061225153}
# seasonDiff: 37 The Augmented Dickey-Fuller test statistic -11.084729,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4492269328800189, '5%': -2.8698573654386559, '10%': -2.5712010851306641}
# seasonDiff: 38 The Augmented Dickey-Fuller test statistic -11.206372,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4492815848836296, '5%': -2.8698813715275406, '10%': -2.5712138845950587}
# seasonDiff: 39 The Augmented Dickey-Fuller test statistic -10.747033,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4493365542737222, '5%': -2.8699055166063085, '10%': -2.5712267582157482}
# seasonDiff: 40 The Augmented Dickey-Fuller test statistic -14.866965,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4492269328800189, '5%': -2.8698573654386559, '10%': -2.5712010851306641}
# seasonDiff: 41 The Augmented Dickey-Fuller test statistic -15.672735,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4492815848836296, '5%': -2.8698813715275406, '10%': -2.5712138845950587}
# seasonDiff: 42 The Augmented Dickey-Fuller test statistic -7.967099,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4495596616468509, '5%': -2.8700035112469626, '10%': -2.5712790073013796}
# seasonDiff: 43 The Augmented Dickey-Fuller test statistic -19.613771,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4493365542737222, '5%': -2.8699055166063085, '10%': -2.5712267582157482}
# seasonDiff: 44 The Augmented Dickey-Fuller test statistic -15.370559,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4494474563375737, '5%': -2.8699542285903887, '10%': -2.5712527305187987}
# seasonDiff: 45 The Augmented Dickey-Fuller test statistic -8.135372,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4497304638968043, '5%': -2.8700785273763487, '10%': -2.5713190051903112}
# seasonDiff: 46 The Augmented Dickey-Fuller test statistic -11.160369,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4496731933105922, '5%': -2.8700533746644323, '10%': -2.5713055939491403}
# seasonDiff: 47 The Augmented Dickey-Fuller test statistic -10.068822,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4497880749874628, '5%': -2.8701038291704251, '10%': -2.5713324959754962}
# seasonDiff: 48 The Augmented Dickey-Fuller test statistic -9.974146,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.449846029628477, '5%': -2.8701292813761641, '10%': -2.5713460670144603}
# seasonDiff: 49 The Augmented Dickey-Fuller test statistic -19.954645,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4496731933105922, '5%': -2.8700533746644323, '10%': -2.5713055939491403}
# seasonDiff: 50 The Augmented Dickey-Fuller test statistic -19.844877,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4497304638968043, '5%': -2.8700785273763487, '10%': -2.5713190051903112}
# seasonDiff: 51 The Augmented Dickey-Fuller test statistic -7.752071,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4500813459011912, '5%': -2.8702326214658069, '10%': -2.5714011682025171}
# seasonDiff: 52 The Augmented Dickey-Fuller test statistic -15.096694,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4499043309021955, '5%': -2.8701548853389252, '10%': -2.5713597190254385}
# seasonDiff: 53 The Augmented Dickey-Fuller test statistic -20.105224,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4499043309021955, '5%': -2.8701548853389252, '10%': -2.5713597190254385}
# seasonDiff: 54 The Augmented Dickey-Fuller test statistic -9.913394,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4502011472639724, '5%': -2.8702852297358983, '10%': -2.5714292194077513}
# seasonDiff: 55 The Augmented Dickey-Fuller test statistic -9.926872,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4502615951739393, '5%': -2.8703117734117742, '10%': -2.5714433728242714}
# seasonDiff: 56 The Augmented Dickey-Fuller test statistic -10.669277,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4502615951739393, '5%': -2.8703117734117742, '10%': -2.5714433728242714}
# seasonDiff: 57 The Augmented Dickey-Fuller test statistic -9.702998,
# pvalue: 0.00
# maximal Lag: 4
# critical values: {'1%': -3.4503836022181056, '5%': -2.8703653471616826, '10%': -2.5714719391912491}
# seasonDiff: 58 The Augmented Dickey-Fuller test statistic -14.385456,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4502615951739393, '5%': -2.8703117734117742, '10%': -2.5714433728242714}
# seasonDiff: 59 The Augmented Dickey-Fuller test statistic -20.591855,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4502615951739393, '5%': -2.8703117734117742, '10%': -2.5714433728242714}
# seasonDiff: 60 The Augmented Dickey-Fuller test statistic -7.767742,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4506321577205279, '5%': -2.870474482366864, '10%': -2.5715301325443787}
# seasonDiff: 61 The Augmented Dickey-Fuller test statistic -19.571088,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4503836022181056, '5%': -2.8703653471616826, '10%': -2.5714719391912491}
# seasonDiff: 62 The Augmented Dickey-Fuller test statistic -14.947621,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4505071137331602, '5%': -2.8704195794076743, '10%': -2.5715008569237532}
# seasonDiff: 63 The Augmented Dickey-Fuller test statistic -7.525616,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4508226600665037, '5%': -2.8705581218686209, '10%': -2.5715747316847342}
# seasonDiff: 64 The Augmented Dickey-Fuller test statistic -19.455793,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4505694423906546, '5%': -2.8704469462727795, '10%': -2.5715154495841017}
# seasonDiff: 65 The Augmented Dickey-Fuller test statistic -20.157992,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4506321577205279, '5%': -2.870474482366864, '10%': -2.5715301325443787}
# seasonDiff: 66 The Augmented Dickey-Fuller test statistic -7.425237,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4510167751522642, '5%': -2.8706433423142599, '10%': -2.5716201744283174}
# seasonDiff: 67 The Augmented Dickey-Fuller test statistic -19.250224,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4507587628808922, '5%': -2.8705300685604991, '10%': -2.5715597727381647}
# seasonDiff: 68 The Augmented Dickey-Fuller test statistic -18.906683,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4508226600665037, '5%': -2.8705581218686209, '10%': -2.5715747316847342}
# seasonDiff: 69 The Augmented Dickey-Fuller test statistic -14.700548,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4509516623840328, '5%': -2.8706147570800784, '10%': -2.5716049316406249}
# seasonDiff: 70 The Augmented Dickey-Fuller test statistic -19.411632,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4509516623840328, '5%': -2.8706147570800784, '10%': -2.5716049316406249}
# seasonDiff: 71 The Augmented Dickey-Fuller test statistic -19.018012,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4510167751522642, '5%': -2.8706433423142599, '10%': -2.5716201744283174}
# seasonDiff: 72 The Augmented Dickey-Fuller test statistic -14.738055,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4511482433628262, '5%': -2.8707010565250752, '10%': -2.5716509501537481}
# seasonDiff: 73 The Augmented Dickey-Fuller test statistic -14.121842,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4512146067362317, '5%': -2.8707301889607111, '10%': -2.5716664849383113}
# seasonDiff: 74 The Augmented Dickey-Fuller test statistic -19.213870,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4512146067362317, '5%': -2.8707301889607111, '10%': -2.5716664849383113}
# seasonDiff: 75 The Augmented Dickey-Fuller test statistic -14.706528,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4513486122290717, '5%': -2.870789013306053, '10%': -2.5716978530569192}
# seasonDiff: 76 The Augmented Dickey-Fuller test statistic -19.889341,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4513486122290717, '5%': -2.870789013306053, '10%': -2.5716978530569192}
# seasonDiff: 77 The Augmented Dickey-Fuller test statistic -18.274178,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4514162625887037, '5%': -2.8708187088091406, '10%': -2.5717136883095675}
# seasonDiff: 78 The Augmented Dickey-Fuller test statistic -19.753550,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4514843502727306, '5%': -2.8708485956333556, '10%': -2.5717296256574622}
# seasonDiff: 79 The Augmented Dickey-Fuller test statistic -14.494343,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4516218546876569, '5%': -2.870908950689806, '10%': -2.5717618106139439}
# seasonDiff: 80 The Augmented Dickey-Fuller test statistic -18.562311,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4516218546876569, '5%': -2.870908950689806, '10%': -2.5717618106139439}
# seasonDiff: 81 The Augmented Dickey-Fuller test statistic -18.633848,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4516912800947299, '5%': -2.8709394227049154, '10%': -2.5717780602423517}
# seasonDiff: 82 The Augmented Dickey-Fuller test statistic -7.600150,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4521175397304784, '5%': -2.8711265007266666, '10%': -2.5718778238516919}
# seasonDiff: 83 The Augmented Dickey-Fuller test statistic -17.981209,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4518314994261337, '5%': -2.8710009653519166, '10%': -2.5718108789483178}
# seasonDiff: 84 The Augmented Dickey-Fuller test statistic -18.817779,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4519023023726696, '5%': -2.8710320399170537, '10%': -2.5718274501260199}
# seasonDiff: 85 The Augmented Dickey-Fuller test statistic -14.222417,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.452045317832011, '5%': -2.8710948055588461, '10%': -2.5718609214854569}
# seasonDiff: 86 The Augmented Dickey-Fuller test statistic -19.594965,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.452045317832011, '5%': -2.8710948055588461, '10%': -2.5718609214854569}
# seasonDiff: 87 The Augmented Dickey-Fuller test statistic -14.151144,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4521902441030963, '5%': -2.8711584068986169, '10%': -2.5718948388228586}
# seasonDiff: 88 The Augmented Dickey-Fuller test statistic -14.503661,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4522634358010391, '5%': -2.8711905261890691, '10%': -2.571911967527952}
# seasonDiff: 89 The Augmented Dickey-Fuller test statistic -5.079030,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# seasonDiff: 90 The Augmented Dickey-Fuller test statistic -13.549344,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4524113009049935, '5%': -2.8712554127251764, '10%': -2.5719465707318712}
# seasonDiff: 91 The Augmented Dickey-Fuller test statistic -10.111505,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4526368785921489, '5%': -2.8713543954331433, '10%': -2.5719993576515705}
# seasonDiff: 92 The Augmented Dickey-Fuller test statistic -13.821305,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4525611751768914, '5%': -2.8713211778255601, '10%': -2.5719816428028888}
# seasonDiff: 93 The Augmented Dickey-Fuller test statistic -19.354660,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4525611751768914, '5%': -2.8713211778255601, '10%': -2.5719816428028888}
# seasonDiff: 94 The Augmented Dickey-Fuller test statistic -9.593864,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4528671172918619, '5%': -2.8714554160827745, '10%': -2.5720532321867466}
# seasonDiff: 95 The Augmented Dickey-Fuller test statistic -18.540829,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4527130998495461, '5%': -2.8713878394577832, '10%': -2.5720171933352485}
# seasonDiff: 96 The Augmented Dickey-Fuller test statistic -4.862622,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4533421678062721, '5%': -2.8716638282872822, '10%': -2.5721643813813451}
# seasonDiff: 97 The Augmented Dickey-Fuller test statistic -18.779464,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4528671172918619, '5%': -2.8714554160827745, '10%': -2.5720532321867466}
# seasonDiff: 98 The Augmented Dickey-Fuller test statistic -16.701118,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4529449243622383, '5%': -2.8714895534256861, '10%': -2.5720714378870331}
# seasonDiff: 99 The Augmented Dickey-Fuller test statistic -18.354567,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4530232710482367, '5%': -2.8715239266718831, '10%': -2.5720897694878424}
# seasonDiff: 100 The Augmented Dickey-Fuller test statistic -9.792837,
# pvalue: 0.00
# maximal Lag: 2
# critical values: {'1%': -3.4532616055293661, '5%': -2.8716284865424599, '10%': -2.5721455328896603}
# seasonDiff: 101 The Augmented Dickey-Fuller test statistic -17.266561,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4531816058796143, '5%': -2.8715933907246418, '10%': -2.5721268156511536}
# seasonDiff: 102 The Augmented Dickey-Fuller test statistic -10.120139,
# pvalue: 0.00
# maximal Lag: 3
# critical values: {'1%': -3.4535050041524245, '5%': -2.8717352599720294, '10%': -2.5722024776854417}
# seasonDiff: 103 The Augmented Dickey-Fuller test statistic -7.036431,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4537536300651999, '5%': -2.8718443180148836, '10%': -2.5722606418188221}
# seasonDiff: 104 The Augmented Dickey-Fuller test statistic -17.507167,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4534232986669546, '5%': -2.8716994185534745, '10%': -2.5721833625116144}
# seasonDiff: 105 The Augmented Dickey-Fuller test statistic -16.962560,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4535050041524245, '5%': -2.8717352599720294, '10%': -2.5722024776854417}
# seasonDiff: 106 The Augmented Dickey-Fuller test statistic -3.090678,
# pvalue: 0.03
# maximal Lag: 14
# critical values: {'1%': -3.4548039258751206, '5%': -2.8723049286186049, '10%': -2.5725063100137175}
# seasonDiff: 107 The Augmented Dickey-Fuller test statistic -9.731670,
# pvalue: 0.00
# maximal Lag: 2
# critical values: {'1%': -3.4538376962008495, '5%': -2.8718811911083093, '10%': -2.5722803076202174}
# seasonDiff: 108 The Augmented Dickey-Fuller test statistic -16.530565,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4537536300651999, '5%': -2.8718443180148836, '10%': -2.5722606418188221}
# seasonDiff: 109 The Augmented Dickey-Fuller test statistic -3.995895,
# pvalue: 0.00
# maximal Lag: 10
# critical values: {'1%': -3.4547128138328875, '5%': -2.8722649771800155, '10%': -2.5724850011573914}
# seasonDiff: 110 The Augmented Dickey-Fuller test statistic -4.580459,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4545326116460702, '5%': -2.8721859575020017, '10%': -2.5724428548618659}
# seasonDiff: 111 The Augmented Dickey-Fuller test statistic -4.390445,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4546223782586534, '5%': -2.8722253212300277, '10%': -2.5724638500216264}
# seasonDiff: 112 The Augmented Dickey-Fuller test statistic -18.152157,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4540935579190495, '5%': -2.8719934111688965, '10%': -2.5723401594120388}
# seasonDiff: 113 The Augmented Dickey-Fuller test statistic -9.105158,
# pvalue: 0.00
# maximal Lag: 2
# critical values: {'1%': -3.4543550558317051, '5%': -2.8721080938842976, '10%': -2.5724013256198348}
# seasonDiff: 114 The Augmented Dickey-Fuller test statistic -16.870698,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4542672521624214, '5%': -2.8720695876977498, '10%': -2.5723807881747534}
# seasonDiff: 115 The Augmented Dickey-Fuller test statistic -5.061564,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4549882099547649, '5%': -2.8723857312734613, '10%': -2.572549407997327}
# seasonDiff: 116 The Augmented Dickey-Fuller test statistic -6.634433,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4548957220044336, '5%': -2.8723451788613157, '10%': -2.5725277783612719}
# seasonDiff: 117 The Augmented Dickey-Fuller test statistic -4.830353,
# pvalue: 0.00
# maximal Lag: 8
# critical values: {'1%': -3.4552699038400827, '5%': -2.8725092359464526, '10%': -2.5726152830188678}
# seasonDiff: 118 The Augmented Dickey-Fuller test statistic -12.955898,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4547128138328875, '5%': -2.8722649771800155, '10%': -2.5724850011573914}
# seasonDiff: 119 The Augmented Dickey-Fuller test statistic -9.084197,
# pvalue: 0.00
# maximal Lag: 2
# critical values: {'1%': -3.4548957220044336, '5%': -2.8723451788613157, '10%': -2.5725277783612719}
# seasonDiff: 120 The Augmented Dickey-Fuller test statistic -4.408805,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4554613060274972, '5%': -2.8725931472675046, '10%': -2.5726600403359887}
# seasonDiff: 121 The Augmented Dickey-Fuller test statistic -9.182986,
# pvalue: 0.00
# maximal Lag: 2
# critical values: {'1%': -3.4550813975770827, '5%': -2.8724265892710914, '10%': -2.5725712007462582}
# seasonDiff: 122 The Augmented Dickey-Fuller test statistic -6.147302,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4554613060274972, '5%': -2.8725931472675046, '10%': -2.5726600403359887}
# seasonDiff: 123 The Augmented Dickey-Fuller test statistic -4.352096,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4557539868570775, '5%': -2.8727214497041422, '10%': -2.5727284763313611}
# seasonDiff: 124 The Augmented Dickey-Fuller test statistic -3.876770,
# pvalue: 0.00
# maximal Lag: 8
# critical values: {'1%': -3.4559529277063419, '5%': -2.8728086526320302, '10%': -2.5727749906856561}
# seasonDiff: 125 The Augmented Dickey-Fuller test statistic -2.223471,
# pvalue: 0.20
# maximal Lag: 14
# critical values: {'1%': -3.4566744514553016, '5%': -2.8731248767783426, '10%': -2.5729436702592023}
# seasonDiff: 126 The Augmented Dickey-Fuller test statistic -4.177234,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4560535712549925, '5%': -2.8728527662442334, '10%': -2.5727985212493754}
# seasonDiff: 127 The Augmented Dickey-Fuller test statistic -16.575123,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4554613060274972, '5%': -2.8725931472675046, '10%': -2.5726600403359887}
# seasonDiff: 128 The Augmented Dickey-Fuller test statistic -13.355802,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4556556713934934, '5%': -2.8726783524898591, '10%': -2.5727054883222502}
# seasonDiff: 129 The Augmented Dickey-Fuller test statistic -16.375009,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4556556713934934, '5%': -2.8726783524898591, '10%': -2.5727054883222502}
# seasonDiff: 130 The Augmented Dickey-Fuller test statistic -3.868577,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4564641849494113, '5%': -2.8730327300984171, '10%': -2.5728945168648161}
# seasonDiff: 131 The Augmented Dickey-Fuller test statistic -2.981338,
# pvalue: 0.04
# maximal Lag: 16
# critical values: {'1%': -3.4575505077947746, '5%': -2.8735087323013526, '10%': -2.5731484348591849}
# seasonDiff: 132 The Augmented Dickey-Fuller test statistic -15.683677,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4559529277063419, '5%': -2.8728086526320302, '10%': -2.5727749906856561}
# seasonDiff: 133 The Augmented Dickey-Fuller test statistic -16.808273,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4560535712549925, '5%': -2.8728527662442334, '10%': -2.5727985212493754}
# seasonDiff: 134 The Augmented Dickey-Fuller test statistic -5.924396,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4566744514553016, '5%': -2.8731248767783426, '10%': -2.5729436702592023}
# seasonDiff: 135 The Augmented Dickey-Fuller test statistic -15.907678,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4562572510874396, '5%': -2.8729420379793598, '10%': -2.5728461399461744}
# seasonDiff: 136 The Augmented Dickey-Fuller test statistic -16.658910,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4563603064099828, '5%': -2.8729872043802356, '10%': -2.5728702325004651}
# seasonDiff: 137 The Augmented Dickey-Fuller test statistic -15.881848,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4564641849494113, '5%': -2.8730327300984171, '10%': -2.5728945168648161}
# seasonDiff: 138 The Augmented Dickey-Fuller test statistic -16.508196,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4565688966099373, '5%': -2.8730786194395455, '10%': -2.5729189953388762}
# seasonDiff: 139 The Augmented Dickey-Fuller test statistic -15.630394,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4566744514553016, '5%': -2.8731248767783426, '10%': -2.5729436702592023}
# seasonDiff: 140 The Augmented Dickey-Fuller test statistic -16.899792,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.456780859712, '5%': -2.8731715065600003, '10%': -2.5729685440000001}
# seasonDiff: 141 The Augmented Dickey-Fuller test statistic -12.670366,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.5730188976326742}
# seasonDiff: 142 The Augmented Dickey-Fuller test statistic -16.976619,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.5730188976326742}
# seasonDiff: 143 The Augmented Dickey-Fuller test statistic -6.053669,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4576641321552009, '5%': -2.8735585105960224, '10%': -2.5731749894132916}
# seasonDiff: 144 The Augmented Dickey-Fuller test statistic -16.452454,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4572152372657472, '5%': -2.8733618415663238, '10%': -2.5730700760129555}
# seasonDiff: 145 The Augmented Dickey-Fuller test statistic -12.507779,
# pvalue: 0.00
# maximal Lag: 1
# critical values: {'1%': -3.4574378249308308, '5%': -2.8734593647265632, '10%': -2.5731220995700079}
# seasonDiff: 146 The Augmented Dickey-Fuller test statistic -3.399216,
# pvalue: 0.01
# maximal Lag: 9
# critical values: {'1%': -3.4584868856997004, '5%': -2.873918902362675, '10%': -2.5733672476233589}
# seasonDiff: 147 The Augmented Dickey-Fuller test statistic -16.405291,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4575505077947746, '5%': -2.8735087323013526, '10%': -2.5731484348591849}
# seasonDiff: 148 The Augmented Dickey-Fuller test statistic -4.129131,
# pvalue: 0.00
# maximal Lag: 7
# critical values: {'1%': -3.4584868856997004, '5%': -2.873918902362675, '10%': -2.5733672476233589}
# seasonDiff: 149 The Augmented Dickey-Fuller test statistic -17.042525,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4577787098622674, '5%': -2.873608704758507, '10%': -2.5732017659819908}
# seasonDiff: 150 The Augmented Dickey-Fuller test statistic -5.715547,
# pvalue: 0.00
# maximal Lag: 5
# critical values: {'1%': -3.4584868856997004, '5%': -2.873918902362675, '10%': -2.5733672476233589}
# seasonDiff: 151 The Augmented Dickey-Fuller test statistic -16.109547,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4580107737197969, '5%': -2.8737103617125186, '10%': -2.5732559963936206}

# %%
w = np.random.normal(size=150).cumsum()
kpss_stat = stattools.kpss(w)
print('Wiener: The KPSS test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ntable distribution: %s' % 
          (kpss_stat[0], kpss_stat[1], kpss_stat[2], kpss_stat[3]))
# Augmented Dickey-Fuller unit root test
df_stat = stattools.adfuller(w)
print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' % 
      (df_stat[0], df_stat[1], df_stat[2], df_stat[4]))
# Out:
# Wiener: The KPSS test statistic 0.233158,
# pvalue: 0.10
# maximal Lag: 14
# table distribution: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The Augmented Dickey-Fuller test statistic -1.709245,
# pvalue: 0.43
# maximal Lag: 0
# critical values: {'1%': -3.4750180242954167, '5%': -2.8811408028842043, '10%': -2.577221358046935}
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1260: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)

# %%
df_stat = stattools.adfuller(np.array(ts['val']))
print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' % 
      (df_stat[0], df_stat[1], df_stat[2], df_stat[4]))
# Out:
# The Augmented Dickey-Fuller test statistic -21.226855,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4472291365835566, '5%': -2.8689795375849223, '10%': -2.5707330834976987}

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train_ts.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train_ts.values.squeeze(), lags=40, ax=ax2)

# %%
def arima_fit(*pdq):
    return sm.tsa.ARIMA(train_ts, (*pdq)).fit()

def arima_fit_aic(*pdq):
    try:
        aic = arima_fit(pdq).aic
        print("ARIMA", pdq, "->", aic)
        return aic
    except:
        return 1e100

# %%
from itertools import product
pdq_cands = product([1, 2], [0], [1, 2])

aics = [(arima_fit_aic(*par), par) for par in pdq_cands]
# Out:
# ARIMA (2, 0, 1) -> 1326.401258597408
# ARIMA (2, 0, 2) -> 1328.3945383963678

# %%
best_pdq = min(aics)[1]
min(aics)
# Out:
# (1326.401258597408, (2, 0, 1))

# %%
model = arima_fit(best_pdq)
model.resid.plot(figsize=(10,4))
plt.show()

df_stat = stattools.adfuller(np.array(model.resid))
print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' % 
      (df_stat[0], df_stat[1], df_stat[2], df_stat[4]))

stat = stats.wilcoxon(model.resid.values)
print('WILCOXON Statistic: %f\npvalue: %.2f' %(stat[0], stat[1]))
# Out:
# The Augmented Dickey-Fuller test statistic -17.561219,
# pvalue: 0.00
# maximal Lag: 0
# critical values: {'1%': -3.4515528795357322, '5%': -2.8708786756338407, '10%': -2.571745666091128}
# WILCOXON Statistic: 22741.000000
# pvalue: 0.29

# %%
pd.DataFrame({'lags':range(30), 'pvalue':sm.stats.diagnostic.acorr_ljungbox(model.resid.values, lags=30)[1], 
              'critial':np.array([0.05]*30)}).set_index('lags').plot(figsize=(15,5))
plt.show()

# %%
test_ts["val_forecast"], test_ts["val_err"] = model.forecast(steps=len(test_ts))[:2]
ts["val_forecast"] = test_ts['val_forecast']
ts["val_forecast_err"] = test_ts['val_err']

def plot_forecast(test):
    plt.figure(figsize=(14, 6))
    plt.plot(ts.index, ts['val'])
    plt.plot(ts.index, ts['val_forecast'], color='red')

    def plus_minus(a, b):
        return (a - b, a + b)

    plt.fill_between(ts.index, *plus_minus(ts['val_forecast'], ts['val_forecast_err']), alpha=0.3, color='red')
    plt.show()
    
    print('MACAPE: %.2f' % qualityMACAPE(ts['val_forecast'], ts['val'])[0])
    
plot_forecast(ts)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# MACAPE: 0.69

# %% [markdown]
# Не вижу никаких значимых результатов даже после работы со стационарностью.
# Опять-таки, кажется, что данные крайне неоднородны, отсюда и сомнительные выводы

# %% [markdown]
# **II. Find the best parameters of ARIMA automaticaly**
# * 0) read data for TS under consideration and use the first 80% of all length of the TS as train TS.
# * 1) plot the graph of the train TS, preprocess data (delete tail, make calendar transformation if needed)
# * 2) stabilize dispersion of train TS through box-cox transformation if needed.
# * 3) Run grid search for ARIMA parameters (use transformed train TS) according to AIC. Use at least 10 distinct values for $p,q,d$. How many time does it take?
# * 4) Build forecast for the initial TS with best ARIMA model selected automaticaly at step 2 (you need to transform it like in step 2).
# * 5) Build forecast interval for the last 20% of transformed TS. Calculate loss MACAPE of your forecast. Does the forecast look appropriate?

# %%
def build_best_arima_model(pdq_cands=None):
    if pdq_cands is None:
        pdq_cands = product(range(10), range(5), range(10))
    aics = [(arima_fit_aic(*par), par) for par in pdq_cands]
    pdq = min(aics)[1]
    model = arima_fit(*pdq)
    return model
                              
def build_and_show_arima_forecast(pdq_cands=None):
    model = build_best_arima_model(pdq_cands)
    test_ts["val_forecast"], test_ts["val_err"] = model.forecast(steps=len(test_ts))[:2]
    ts["val_forecast"] = test_ts['val_forecast']
    ts["val_forecast_err"] = test_ts['val_err']
    plot_forecast(ts)
    
    
build_and_show_arima_forecast()
# Out:
# ARIMA (0, 0, 0) -> 1327.6264191
# ARIMA (0, 0, 1) -> 1327.8623032058185
# ARIMA (0, 0, 2) -> 1324.6267864046838
# ARIMA (0, 0, 3) -> 1326.473890595019
# ARIMA (0, 0, 4) -> 1328.139335076399
# ARIMA (0, 0, 5) -> 1329.579478490837
# ARIMA (0, 0, 6) -> 1329.3231192105638
# ARIMA (0, 0, 7) -> 1331.3077519552812
# ARIMA (0, 0, 8) -> 1330.7053230554748
# ARIMA (0, 0, 9) -> 1332.364934449801
# ARIMA (0, 1, 0) -> 1558.85366846
# ARIMA (0, 1, 1) -> 1331.8951147087505
# ARIMA (0, 2, 0) -> 1890.16941565
# ARIMA (0, 2, 1) -> 1562.578830895281
# ARIMA (1, 0, 0) -> 1328.292790307204
# ARIMA (1, 1, 0) -> 1481.1908866229746
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (1, 1, 6) -> 1336.0382611159282
# ARIMA (1, 2, 0) -> 1729.8234417559397
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:473: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# ARIMA (1, 2, 3) -> 1348.0311697173963
# ARIMA (2, 0, 0) -> 1325.7101673834534
# ARIMA (2, 0, 1) -> 1326.401258597408
# ARIMA (2, 0, 2) -> 1328.3945383963678
# ARIMA (2, 1, 0) -> 1435.5899341726185
# ARIMA (2, 1, 1) -> 1330.2397081885317
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (2, 1, 6) -> 1338.0254099019437
# ARIMA (2, 2, 0) -> 1632.213112345015
# ARIMA (3, 0, 0) -> 1327.1162850351125
# ARIMA (3, 0, 1) -> 1328.385812011787
# ARIMA (3, 0, 2) -> 1330.2878680968283
# ARIMA (3, 1, 0) -> 1417.803710505831
# ARIMA (3, 1, 1) -> 1331.6979362995057
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (3, 1, 6) -> 1339.2064375632417
# ARIMA (3, 2, 0) -> 1587.262786778307
# ARIMA (4, 0, 0) -> 1327.0677517649974
# ARIMA (4, 0, 1) -> 1329.0647871757392
# ARIMA (4, 0, 2) -> 1330.7620196997545
# ARIMA (4, 0, 3) -> 1331.3630085475352
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 0, 4) -> 1330.9726308124787
# ARIMA (4, 1, 0) -> 1396.9588050408656
# ARIMA (4, 1, 1) -> 1331.7077193129114
# ARIMA (4, 1, 2) -> 1333.7337997433708
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 1, 3) -> 1334.8406230768
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 1, 4) -> 1337.6631341761665
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 1, 6) -> 1337.5747923424083
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 1, 8) -> 1345.0666816708654
# ARIMA (4, 2, 0) -> 1551.8515415662105
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (4, 2, 6) -> 1355.8856952303759
# ARIMA (5, 0, 0) -> 1329.0616929155556
# ARIMA (5, 0, 1) -> 1329.9412431299017
# ARIMA (5, 0, 2) -> 1330.6621417501651
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 0, 3) -> 1333.3383783382553
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 0, 5) -> 1332.3412858177385
# ARIMA (5, 1, 0) -> 1380.5340173783418
# ARIMA (5, 1, 1) -> 1333.7279735456955
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 1, 2) -> 1334.8913236483543
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:654: RuntimeWarning: invalid value encountered in log
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:628: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:628: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:629: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:629: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:654: RuntimeWarning: divide by zero encountered in true_divide
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 1, 5) -> 1333.8051855221347
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 1, 6) -> 1335.444157456138
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (5, 1, 8) -> 1347.675742951472
# ARIMA (5, 2, 0) -> 1517.7531248815603
# ARIMA (6, 0, 0) -> 1330.4956251327333
# ARIMA (6, 0, 1) -> 1331.25718322607
# ARIMA (6, 0, 2) -> 1332.458923916267
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 0, 4) -> 1333.8527278447027
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 0, 5) -> 1333.872681877591
# ARIMA (6, 1, 0) -> 1372.9645711523788
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 1) -> 1335.1179555929286
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 2) -> 1336.4552143290564
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 3) -> 1337.8895054925072
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 4) -> 1340.6585609687686
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 6) -> 1348.4025367111763
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 7) -> 1345.7179638626271
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (6, 1, 8) -> 1348.8340421746095
# ARIMA (6, 2, 0) -> 1500.8763488560896
# ARIMA (7, 0, 0) -> 1332.4008690716832
# ARIMA (7, 0, 1) -> 1333.5106079194422
# ARIMA (7, 1, 0) -> 1359.0421107508091
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 1) -> 1337.0009449443958
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 2) -> 1338.2421999490134
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 3) -> 1339.5913568843746
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 4) -> 1338.6263641294806
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 5) -> 1345.1173986974254
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 6) -> 1341.5748101364572
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 7) -> 1342.6454272007818
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 1, 8) -> 1342.1805516772042
# ARIMA (7, 2, 0) -> 1470.2999298395703
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (7, 2, 1) -> 1366.910205064577
# ARIMA (8, 0, 0) -> 1330.880946734821
# ARIMA (8, 0, 1) -> 1332.8566821685788
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 2) -> 1330.3962728943602
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 3) -> 1332.2857656374679
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 4) -> 1333.893167254293
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 5) -> 1340.544683012937
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 6) -> 1339.250938891626
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 7) -> 1341.6629140491166
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 0, 8) -> 1347.0570116920346
# ARIMA (8, 1, 0) -> 1358.3734396947787
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 1, 2) -> 1337.3523999268173
# ARIMA (8, 2, 0) -> 1456.199385398929
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:584: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:585: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:585: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:586: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:587: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:587: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# ARIMA (8, 2, 1) -> 1366.4292055373419
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 2, 2) -> 1370.8087274193533
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (8, 2, 3) -> 1367.116688624439
# ARIMA (9, 0, 0) -> 1332.8770324571246
# ARIMA (9, 0, 1) -> 1334.5827113177338
# ARIMA (9, 0, 2) -> 1336.3892432656232
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 3) -> 1333.6674491504227
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 4) -> 1336.7912343204766
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 5) -> 1337.2124006814627
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 6) -> 1348.1298280703109
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 7) -> 1343.0518840196632
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 0, 8) -> 1349.7688756890814
# ARIMA (9, 1, 0) -> 1355.8765649348893
# ARIMA (9, 1, 1) -> 1337.3546499457411
# ARIMA (9, 2, 0) -> 1436.9546967407578
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 2, 1) -> 1364.3921011620232
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 2, 2) -> 1369.0879653434804
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA (9, 2, 3) -> 1372.0405161239694
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-6325160752f5> in <module>()
#      15
#      16
# ---> 17 build_and_show_arima_forecast()
#
# <ipython-input-65-6325160752f5> in build_and_show_arima_forecast(pdq_cands)
#       8
#       9 def build_and_show_arima_forecast(pdq_cands=None):
# ---> 10     model = build_best_arima_model(pdq_cands)
#      11     test_ts["val_forecast"], test_ts["val_err"] = model.forecast(steps=len(test_ts))[:2]
#      12     ts["val_forecast"] = test_ts['val_forecast']
#
# <ipython-input-65-6325160752f5> in build_best_arima_model(pdq_cands)
#       4     aics = [(arima_fit_aic(*par), par) for par in pdq_cands]
#       5     pdq = min(aics)[1]
# ----> 6     model = arima_fit(*pdq)
#       7     return model
#       8
#
# <ipython-input-59-fc13d5a46a77> in arima_fit(*pdq)
#       1 def arima_fit(*pdq):
# ----> 2     return sm.tsa.ARIMA(train_ts, (*pdq)).fit()
#       3
#       4 def arima_fit_aic(*pdq):
#       5     try:
#
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     993     def __new__(cls, endog, order, exog=None, dates=None, freq=None,
#     994                 missing='none'):
# --> 995         p, d, q = order
#     996         if d == 0:  # then we just use an ARMA model
#     997             return ARMA(endog, (p, q), exog, dates, freq, missing)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Оно крашнулось. Поищем результат среди почитанных

# %%
parsed_results = (1326.401258597408, (2, 0, 1))

# %%
def build_and_show_forecast(model):
    test_ts["val_forecast"], test_ts["val_err"] = model.forecast(steps=len(test_ts))[0], model.forecast(steps=len(test_ts))[1]
    ts["val_forecast"] = test_ts['val_forecast']
    ts["val_forecast_err"] = test_ts['val_err']
    plot_forecast(ts)
    
model = arima_fit((parsed_results)[1])

build_and_show_forecast(model)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# MACAPE: 0.69

# %% [markdown]
# Собственно, результат остался тем же. Слишком "неанализируемые" данные + слабая работа по их сглаживанию и подбору параметров. Сделал всё что мог
